# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os, sys
from pathlib import Path
current_dir = os.getcwd()
parent_dir = os.path.dirname(current_dir)
sys.path.append(str(parent_dir))
from functions_roman_rubin import read_data

path_model = str(parent_dir)+'/test_sim_fit/Event_18.h5'
info, params, bands = read_data(path_model)

for b in bands:
    plt.errorbar(bands[b]['time'],bands[b]['mag'],bands[b]['err_mag'])
plt.show()

# %%
from pyLIMA.outputs import plot
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 from pyLIMA.outputs import plot
#
# ImportError: cannot import name 'plot' from 'pyLIMA.outputs' (/home/anibal/anaconda3/envs/pyLIMA/lib/python3.9/site-packages/pyLIMA/outputs/__init__.py)
